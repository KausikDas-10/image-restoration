# %%
# Mount the drive.
# Load model from the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/ucolor/test_tf.py

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv

# %%
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)

# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.5659330919999945
# GPU (s):
# 0.10216799200000537
# GPU speedup over CPU: 34x

# %%
# %env PYTHONPATH = # /env/python
# Out:
# env: PYTHONPATH=# /env/python

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update conda

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# !conda create -n myenv python=3.5.6

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install protobuf==3.19.6
# # pip install tensorflow==1.5.0
# pip install tensorflow-gpu==1.5.0

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install pillow
# pip install h5py
# pip install matplotlib
# pip install scipy
# pip install imageio==2.0.0

# %%
# !cat /etc/*release

# %%
# Out:
# --2023-12-27 09:06:00--  https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.195.19.142
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.195.19.142|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-12-27 09:06:00 ERROR 404: Not Found.

# %%
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# # python /content/drive/MyDrive/ucolor/main_test.py
# python /content/drive/MyDrive/ucolor/test_tf.py

# %%
# !pip install imageio==2.33.1
# !pip install pillow
# !pip install h5py
# !pip install matplotlib
# !pip install scipy

# %%
import imageio
from PIL import Image
import PIL

# %%
# !python3 /content/drive/MyDrive/ucolor/main_test.py
# Out:
# 2024-02-16 13:31:44.479506: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-16 13:31:44.479560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-16 13:31:44.480872: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-16 13:31:44.488068: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-16 13:31:45.456935: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-16 13:31:50.224028: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:50.791379: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:50.791801: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {'?': <absl.app.HelpFlag object at 0x7f2e35140be0>,
#  'alsologtostderr': <absl.flags._flag.BooleanFlag object at 0x7f2ea4d3dcf0>,
#  'batch_size': <absl.flags._flag.Flag object at 0x7f2eabac7f40>,
#  'beta1': <absl.flags._flag.Flag object at 0x7f2e35140970>,
#  'c_depth_dim': <absl.flags._flag.Flag object at 0x7f2e35140a30>,
#  'c_dim': <absl.flags._flag.Flag object at 0x7f2e351409d0>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7f2e35140a90>,
#  'delta_threshold': <absl.flags._flag.Flag object at 0x7f2e6cf8bbb0>,
#  'epoch': <absl.flags._flag.Flag object at 0x7f2eabac7fa0>,
#  'hbm_oom_exit': <absl.flags._flag.BooleanFlag object at 0x7f2e6cdc67a0>,
#  'help': <absl.app.HelpFlag object at 0x7f2e35140be0>,
#  'helpfull': <absl.app.HelpfullFlag object at 0x7f2e35140bb0>,
#  'helpshort': <absl.app.HelpshortFlag object at 0x7f2e35140c10>,
#  'helpxml': <absl.app.HelpXMLFlag object at 0x7f2e35140c40>,
#  'image_height': <absl.flags._flag.Flag object at 0x7f2eabac7f70>,
#  'image_width': <absl.flags._flag.Flag object at 0x7f2e420c6650>,
#  'is_train': <absl.flags._flag.BooleanFlag object at 0x7f2e35140b80>,
#  'label_height': <absl.flags._flag.Flag object at 0x7f2e350e7df0>,
#  'label_width': <absl.flags._flag.Flag object at 0x7f2e35140100>,
#  'learning_rate': <absl.flags._flag.Flag object at 0x7f2e35140910>,
#  'log_dir': <absl.flags._flag.Flag object at 0x7f2ea4d3dd50>,
#  'logger_levels': <absl.logging._LoggerLevelsFlag object at 0x7f2ea4d3de40>,
#  'logtostderr': <absl.flags._flag.BooleanFlag object at 0x7f2ea4d3dbd0>,
#  'only_check_args': <absl.flags._flag.BooleanFlag object at 0x7f2ea4d3e440>,
#  'op_conversion_fallback_to_while_loop': <absl.flags._flag.BooleanFlag object at 0x7f2e6f862a70>,
#  'pdb': <absl.flags._defines.DEFINE_alias.<locals>._FlagAlias object at 0x7f2ea4e67d30>,
#  'pdb_post_mortem': <absl.flags._flag.BooleanFlag object at 0x7f2ea4e67c10>,
#  'profile_file': <absl.flags._flag.Flag object at 0x7f2ea4d3e470>,
#  'run_with_pdb': <absl.flags._flag.BooleanFlag object at 0x7f2ea4e67bb0>,
#  'run_with_profiling': <absl.flags._flag.BooleanFlag object at 0x7f2ea4d3cc40>,
#  'runtime_oom_exit': <absl.flags._flag.BooleanFlag object at 0x7f2e6cdc6830>,
#  'sample_dir': <absl.flags._flag.Flag object at 0x7f2e35140af0>,
#  'showprefixforinfo': <absl.flags._flag.BooleanFlag object at 0x7f2ea4d3df90>,
#  'stderrthreshold': <absl.logging._StderrthresholdFlag object at 0x7f2ea4d3df00>,
#  'test_data_dir': <absl.flags._flag.Flag object at 0x7f2e35140b50>,
#  'test_random_seed': <absl.flags._flag.Flag object at 0x7f2e6cbf9d20>,
#  'test_randomize_ordering_seed': <absl.flags._flag.Flag object at 0x7f2e6cbf9c90>,
#  'test_srcdir': <absl.flags._flag.Flag object at 0x7f2e6cd7efe0>,
#  'test_tmpdir': <absl.flags._flag.Flag object at 0x7f2e6cbf8bb0>,
#  'tt_check_filter': <absl.flags._flag.BooleanFlag object at 0x7f2e6cf8bcd0>,
#  'tt_single_core_summaries': <absl.flags._flag.BooleanFlag object at 0x7f2e6cf8ba60>,
#  'use_cprofile_for_profiling': <absl.flags._flag.BooleanFlag object at 0x7f2ea4d3e4a0>,
#  'v': <absl.logging._VerbosityFlag object at 0x7f2ea4d3dd80>,
#  'verbosity': <absl.logging._VerbosityFlag object at 0x7f2ea4d3dd80>,
#  'xml_output_file': <absl.flags._flag.Flag object at 0x7f2e6cbf8be0>}
# test_data_list: 	 ['/content/drive/MyDrive/ucolor/input_90/LFT_3374.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3375.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3376.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3377.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3378.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3379.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3380.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3381.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3382.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3383.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3384.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3385.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3386.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3387.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3388.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3389.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3390.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3391.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3392.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3393.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3394.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3395.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3396.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3397.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3398.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3399.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3400.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3401.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3402.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3403.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3404.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3405.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3406.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3407.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3408.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3409.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3410.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3411.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3412.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3413.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3414.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3415.png', '/content/drive/MyDrive/ucolor/input_90/LFT_3416.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0153.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0154.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0155.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0156.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0157.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0158.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0159.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0160.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0161.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0162.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0163.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0164.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0165.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0166.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0167.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0168.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0169.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0170.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0171.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0172.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0173.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0174.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0175.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0176.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0177.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0178.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0179.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0180.png', '/content/drive/MyDrive/ucolor/input_90/RGT_0181.png', '/content/drive/MyDri ...
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3374.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3374.png
# 2024-02-16 13:31:53.633932: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:53.634319: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:53.634513: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:53.754831: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:53.755220: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:53.755368: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-02-16 13:31:53.755467: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:31:53.755610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3374.png
# /content/drive/MyDrive/ucolor/ops.py:258: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.compat.v1.layers.dense(inputs=x, use_bias=False, units=units)
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# W0216 13:31:55.387755 139838431736448 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3374.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3374.png
# 2024-02-16 13:31:56.118393: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# self.checkpoint_dir: 	 /content/drive/MyDrive/ucolor/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
# I0216 13:31:57.169952 139838431736448 saver.py:1413] Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
#  [*] Load SUCCESS
# 2024-02-16 13:32:09.778701: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 54.03918719291687
# result_h: h, w, c: 	 632 1024 3
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3375.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3375.png
# 2024-02-16 13:33:05.166407: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:05.166884: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:05.167175: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:05.167500: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:05.167785: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:05.167954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3375.png
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3375.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3375.png
# self.checkpoint_dir: 	 /content/drive/MyDrive/ucolor/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
# I0216 13:33:07.248799 139838431736448 saver.py:1413] Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
#  [*] Load SUCCESS
# 6.0571370124816895
# result_h: h, w, c: 	 632 1024 3
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3376.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3376.png
# 2024-02-16 13:33:27.229632: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:27.230089: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:27.230356: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:27.230618: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:27.230840: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:27.230991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3376.png
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3376.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3376.png
# self.checkpoint_dir: 	 /content/drive/MyDrive/ucolor/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
# I0216 13:33:29.499104 139838431736448 saver.py:1413] Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
#  [*] Load SUCCESS
# 5.57747220993042
# result_h: h, w, c: 	 632 1024 3
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3377.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3377.png
# 2024-02-16 13:33:37.176259: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:37.176669: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:37.176953: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:37.177266: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:37.177507: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:37.177701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3377.png
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3377.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3377.png
# self.checkpoint_dir: 	 /content/drive/MyDrive/ucolor/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
# I0216 13:33:40.153809 139838431736448 saver.py:1413] Restoring parameters from /content/drive/MyDrive/ucolor/checkpoint/coarse_128/coarse.model
#  [*] Load SUCCESS
# 5.458701848983765
# result_h: h, w, c: 	 632 1024 3
# path:  /content/drive/MyDrive/ucolor/input_90/LFT_3378.png
# path:  /content/drive/MyDrive/ucolor/gdcp_90/LFT_3378.png
# 2024-02-16 13:33:47.726966: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:47.727325: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:47.727521: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33:47.727813: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-16 13:33