# %% [markdown]
# *   The model run on the Tensorflow==1.0.0.
# *   To install Tensorflow==1.0.0, we need first install python==3.5 version.
# *   Here we install python=3.5 in the conda enviroment
# *   Then, install the Tensorflow==1.0.0 in the same conda enviroment
# *   Initialize the conda env. and run the main code.

# %%
# Mount the drive.
# Load model from the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update conda
# Out:
# --2024-01-26 06:15:13--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76120962 (73M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py38_4.1 100%[===================>]  72.59M   137MB/s    in 0.5s
#
# 2024-01-26 06:15:14 (137 MB/s) - ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’ saved [76120962/76120962]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py38h06a4308_2
# ...

# %%
# !conda create -n myenv python=3.5.6
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.5.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.6.20          |     pyhd3eb1b0_3         155 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-10.0.1                 |           py35_0         1.6 MB
#     python-3.5.6               |       h12debd9_1        24.9 MB
#     setuptools-40.2.0          |           py35_0         490 KB
#     ------------------------------------------------------------
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install protobuf==3.19.6
# pip install tensorflow==1.0.0
# # pip install tensorflow-gpu==1.5.0
# Out:
# ...
#     100% |████████████████████████████████| 163kB 2.9MB/s
# ...
#     100% |████████████████████████████████| 44.1MB 661kB/s
# ...
#     100% |████████████████████████████████| 19.9MB 748kB/s
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install pillow
# pip install h5py
# pip install matplotlib
# pip install scipy
# pip install imageio==2.0.0
# Out:
# ...
#     100% |████████████████████████████████| 2.2MB 2.7MB/s
# ...
#     100% |████████████████████████████████| 2.8MB 4.0MB/s
# ...
#     100% |████████████████████████████████| 13.0MB 3.2MB/s
# ...
#     100% |████████████████████████████████| 71kB 29.0MB/s
# ...
#     100% |████████████████████████████████| 256kB 42.0MB/s
# ...
#     100% |████████████████████████████████| 92kB 34.0MB/s
# ...
#     100% |████████████████████████████████| 26.0MB 1.7MB/s
# ...
#     100% |████████████████████████████████| 3.3MB 11.3MB/s
# ...
#   Running setup.py bdist_wheel for imageio ... done
#   Stored in directory: /root/.cache/pip/wheels/ea/6f/30/b50d09284034f02b75182f91ae5b35042401597d02fd16035a
# Successfully built imageio
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# # python /content/drive/MyDrive/ucolor/main_test.py
# python /content/drive/MyDrive/UWCNN_v2/main_test.py
